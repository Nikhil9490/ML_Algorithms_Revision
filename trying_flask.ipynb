# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil9490/ML_Algorithms_Revision/blob/main/trying_flask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install flask

# %%
from flask import Flask
from threading import Thread
from google.colab import output

app = Flask(__name__)

@app.route("/")
def home():
    return "Hello from Flask in Colab!"

def run_app():
    app.run(host="0.0.0.0", port=8000)

# start Flask in the background
Thread(target=run_app, daemon=True).start()

# open it in a new browser window / tab managed by Colab
output.serve_kernel_port_as_window(8000)
# if that gives issues, try:
# output.serve_kernel_port_as_iframe(8000)
# Out:
# ...
# Try `serve_kernel_port_as_iframe` instead.
#  * Serving Flask app '__main__'
#  * Debug mode: off
